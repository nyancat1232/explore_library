# %%
import sklearn as fff

# %%
import pprint
def find_module(module,hide_double_underscored=False,_current_depth=0):
    if _current_depth>2:
        return None
    result={}
    for lib in dir(module):
        if lib.startswith('__') and hide_double_underscored:
            continue
        
        result[lib]=find_module(module,hide_double_underscored=hide_double_underscored,_current_depth=_current_depth+1)
    return result

r=find_module(fff,hide_double_underscored=True)
pprint.pprint(r)
# Out:
# {'_config': {'_config': {'_config': None,
#                          '_distributor_init': None,
#                          'base': None,
#                          'clone': None,
#                          'config_context': None,
#                          'exceptions': None,
#                          'externals': None,
#                          'get_config': None,
#                          'logger': None,
#                          'logging': None,
#                          'os': None,
#                          'random': None,
#                          'set_config': None,
#                          'setup_module': None,
#                          'show_versions': None,
#                          'sys': None,
#                          'utils': None},
#              '_distributor_init': {'_config': None,
#                                    '_distributor_init': None,
#                                    'base': None,
#                                    'clone': None,
#                                    'config_context': None,
#                                    'exceptions': None,
#                                    'externals': None,
#                                    'get_config': None,
#                                    'logger': None,
#                                    'logging': None,
#                                    'os': None,
#                                    'random': None,
#                                    'set_config': None,
#                                    'setup_module': None,
#                                    'show_versions': None,
#                                    'sys': None,
#                                    'utils': None},
#              'base': {'_config': None,
#                       '_distributor_init': None,
#                       'base': None,
#                       'clone': None,
#                       'config_context': None,
#                       'exceptions': None,
#                       'externals': None,
#                       'get_config': None,
#                       'logger': None,
#                       'logging': None,
#                       'os': None,
#                       'random': None,
#                       'set_config': None,
#                       'setup_module': None,
#                       'show_versions': None,
#                       'sys': None,
#                       'utils': None},
#              'clone': {'_config': None,
#                        '_distributor_init': None,
#                        'base': None,
#                        'clone': None,
#                        'config_context': None,
#                        'exceptions': None,
#                        'externals': None,
#                        'get_config': None,
#                        'logger': None,
#                        'logging': None,
#                        'os': None,
#                        'random': None,
#                        'set_config': None,
#                        'setup_module': None,
#                        'show_versions': None,
#                        'sys': None,
#                        'utils': None},
#              'config_context': {'_config': None,
#                                 '_distributor_init': None,
#                                 'base': None,
#                                 'clone': None,
#                                 'config_context': None,
#                                 'exceptions': None,
#                                 'externals': None,
#                                 'get_config': None,
#                                 'logger': None,
#                                 'logging': None,
#                                 'os': None,
#                                 'random': None,
#                                 'set_config': None,
#                                 'setup_module': None,
#                                 'show_versions': None,
#                                 'sys': None,
#                                 'utils': None},
#              'exceptions': {'_config': None,
#                             '_distributor_init': None,
#                             'base': None,
#                             'clone': None,
#                             'config_context': None,
#                             'exceptions': None,
#                             'externals': None,
#                             'get_config': None,
#                             'logger': None,
#                             'logging': None,
#                             'os': None,
#                             'random': None,
#                             'set_config': None,
#                             'setup_module': None,
#                             'show_versions': None,
#                             'sys': None,
#                             'utils': None},
#              'externals': {'_config': None,
#                            '_distributor_init': None,
#                            'base': None,
#                            'clone': None,
#                            'config_context': None,
#                            'exceptions': None,
#                            'externals': None,
#                            'get_config': None,
#                            'logger': None,
#                            'logging': None,
#                            'os': None,
#                            'random': None,
#                            'set_config': None,
#                            'setup_module': None,
#                            'show_versions': None,
#                            'sys': None,
#                            'utils': None},
#              'get_config': {'_config': None,
#                             '_distributor_init': None,
#                             'base': None,
#                             'clone': None,
#                             'config_context': None,
#                             'exceptions': None,
#                             'externals': None,
#                             'get_config': None,
#                             'logger': None,
#                             'logging': None,
#                             'os': None,
#                             'random': None,
#                             'set_config': None,
#                             'setup_module': None,
#                             'show_versions': None,
#                             'sys': None,
#                             'utils': None},
#              'logger': {'_config': None,
#                         '_distributor_init': None,
#                         'base': None,
#                         'clone': None,
#                         'config_context': None,
#                         'exceptions': None,
#                         'externals': None,
#                         'get_config': None,
#                         'logger': None,
#                         'logging': None,
#                         'os': None,
#                         'random': None,
#                         'set_config': None,
#                         'setup_module': None,
#                         'show_versions': None,
#                         'sys': None,
#                         'utils': None},
#              'logging': {'_config': None,
#                          '_distributor_init': None,
#                          'base': None,
#                          'clone': None,
#                          'config_context': None,
#                          'exceptions': None,
#                          'externals': None,
#                          'get_config': None,
#                          'logger': None,
#                          'logging': None,
#                          'os': None,
#                          'random': None,
#                          'set_config': None,
#                          'setup_module': None,
#                          'show_versions': None,
#                          'sys': None,
#                          'utils': None},
#              'os': {'_config': None,
#                     '_distributor_init': None,
#                     'base': None,
#                     'clone': None,
#                     'config_context': None,
#                     'exceptions': None,
#                     'externals': None,
#                     'get_config': None,
#                     'logger': None,
#                     'logging': None,
#                     'os': None,
#                     'random': None,
#                     'set_config': None,
#                     'setup_module': None,
#                     'show_versions': None,
#                     'sys': None,
#                     'utils': None},
#              'random': {'_config': None,
#                         '_distributor_init': None,
#                         'base': None,
#                         'clone': None,
#                         'config_context': None,
#                         'exceptions': None,
#                         'externals': None,
#                         'get_config': None,
#                         'logger': None,
#                         'logging': None,
#                         'os': None,
#                         'random': None,
#                         'set_config': None,
#                         'setup_module': None,
#                         'show_versions': None,
#                         'sys': None,
#                         'utils': None},
#              'set_config': {'_config': None,
#                             '_distributor_init': None,
#                             'base': None,
#                             'clone': None,
#                             'config_context': None,
#                             'exceptions': None,
#                             'externals': None,
#                             'get_config': None,
#                             'logger': None,
#                             'logging': None,
#                             'os': None,
#                             'random': None,
#                             'set_config': None,
#                             'setup_module': None,
#                             'show_versions': None,
#                             'sys': None,
#                             'utils': None},
#              'setup_module': {'_config': None,
#                               '_distributor_init': None,
#                               'base': None,
#                               'clone': None,
#                               'config_context': None,
#                               'exceptions': None,
#                               'externals': None,
#                               'get_config': None,
#                               'logger': None,
#                               'logging': None,
#                               'os': None,
#                               'random': None,
#                               'set_config': None,
#                               'setup_module': None,
#                               'show_versions': None,
#                               'sys': None,
#                               'utils': None},
#              'show_versions': {'_config': None,
#                                '_distributor_init': None,
#                                'base': None,
#                                'clone': None,
#                                'config_context': None,
#                                'exceptions': None,
#                                'externals': None,
#                                'get_config': None,
#                                'logger': None,
#                                'logging': None,
#                                'os': None,
#                                'random': None,
#                                'set_config': None,
#                                'setup_module': None,
#                                'show_versions': None,
#                                'sys': None,
#                                'utils': None},
#              'sys': {'_config': None,
#                      '_distributor_init': None,
#                      'base': None,
#                      'clone': None,
#                      'config_context': None,
#                      'exceptions': None,
#                      'externals': None,
#                      'get_config': None,
#                      'logger': None,
#                      'logging': None,
#                      'os': None,
#                      'random': None,
#                      'set_config': None,
#                      'setup_module': None,
#                      'show_versions': None,
#                      'sys': None,
#                      'utils': None},
#              'utils': {'_config': None,
#                        '_distributor_init': None,
#                        'base': None,
#                        'clone': None,
#                        'config_context': None,
#                        'exceptions': None,
#                        'externals': None,
#                        'get_config': None,
#                        'logger': None,
#                        'logging': None,
#                        'os': None,
#                        'random': None,
#                        'set_config': None,
#                        'setup_module': None,
#                        'show_versions': None,
#                        'sys': None,
#                        'utils': None}},
#  '_distributor_init': {'_config': {'_config': None,
#                                    '_distributor_init': None,
#                                    'base': None,
#                                    'clone': None,
#                                    'config_context': None,
#                                    'exceptions': None,
#                                    'externals': None,
#                                    'get_config': None,
#                                    'logger': None,
#                                    'logging': None,
#                                    'os': None,
#                                    'random': None,
#                                    'set_config': None,
#                                    'setup_module': None,
#                                    'show_versions': None,
#                                    'sys': None,
#                                    'utils': None},
#                        '_distributor_init': {'_config': None,
#                                              '_distributor_init': None,
#                                              'base': None,
#                                              'clone': None,
#                                              'config_context': None,
#                                              'exceptions': None,
#                                              'externals': None,
#                                              'get_config': None,
#                                              'logger': None,
#                                              'logging': None,
#                                              'os': None,
#                                              'random': None,
#                                              'set_config': None,
#                                              'setup_module': None,
#                                              'show_versions': None,
#                                              'sys': None,
#                                              'utils': None},
#                        'base': {'_config': None,
#                                 '_distributor_init': None,
#                                 'base': None,
#                                 'clone': None,
#                                 'config_context': None,
#                                 'exceptions': None,
#                                 'externals': None,
#                                 'get_config': None,
#                                 'logger': None,
#                                 'logging': None,
#                                 'os': None,
#                                 'random': None,
#                                 'set_config': None,
#                                 'setup_module': None,
#                                 'show_versions': None,
#                                 'sys': None,
#                                 'utils': None},
#                        'clone': {'_config': None,
#                                  '_distributor_init': None,
#                                  'base': None,
#                                  'clone': None,
#                                  'config_context': None,
#                                  'exceptions': None,
#                                  'externals': None,
#                                  'get_config': None,
#                                  'logger': None,
#                                  'logging': None,
#                                  'os': None,
#                                  'random': None,
#                                  'set_config': None,
#                                  'setup_module': None,
#                                  'show_versions': None,
#                                  'sys': None,
#                                  'utils': None},
#                        'config_context': {'_config': None,
#                                           '_distributor_init': None,
#                                           'base': None,
#                                           'clone': None,
#                                           'config_context': None,
#                                           'exceptions': None,
#                                           'externals': None,
#                                           'get_config': None,
#                                           'logger': None,
#                                           'logging': None,
#                                           'os': None,
#                                           'random': None,
#                                           'set_config': None,
#                                           'setup_module': None,
#                                           'show_versions': None,
#                                           'sys': None,
#                                           'utils': None},
#                        'exceptions': {'_config': None,
#                                       '_distributor_init': None,
#                                       'base': None,
#                                       'clone': None,
#                                       'config_context': None,
#                                       'exceptions': None,
#                                       'externals': None,
#                                       'get_config': None,
#                                       'logger': None,
#                                       'logging': None,
#                                       'os': None,
#                                       'random': None,
#                                       'set_config': None,
#                                       'setup_module': None,
#                                       'show_versions': None,
#                                       'sys': None,
#                                       'utils': None},
#                        'externals': {'_config': None,
#                                      '_distributor_init': None,
#                                      'base': None,
#                                      'clone': None,
#                                      'config_context': None,
#                                      'exceptions': None,
#                                      'externals': None,
#                                      'get_config': None,
#                                      'logger': None,
#                                      'logging': None,
#                                      'os': None,
#                                      'random': None,
#                                      'set_config': None,
#                                      'setup_module': None,
#                                      'show_versions': None,
#                                      'sys': None,
#                                      'utils': None},
#                        'get_config': {'_config': None,
#                                       '_distributor_init': None,
#                                       'base': None,
#                                       'clone': None,
#                                       'config_context': None,
#                                       'exceptions': None,
#                                       'externals': None,
#                                       'get_config': None,
#                                       'logger': None,
#                                       'logging': None,
#                                       'os': None,
#                                       'random': None,
#                                       'set_config': None,
#                                       'setup_module': None,
#                                       'show_versions': None,
#                                       'sys': None,
#                                       'utils': None},
#                        'logger': {'_config': None,
#                                   '_distributor_init': None,
#                                   'base': None,
#                                   'clone': None,
#                                   'config_context': None,
#                                   'exceptions': None,
#                                   'externals': None,
#                                   'get_config': None,
#                                   'logger': None,
#                                   'logging': None,
#                                   'os': None,
#                                   'random': None,
#                                   'set_config': None,
#                                   'setup_module': None,
#                                   'show_versions': None,
#                                   'sys': None,
#                                   'utils': None},
#                        'logging': {'_config': None,
#                                    '_distributor_init': None,
#                                    'base': None,
#                                    'clone': None,
#                                    'config_context': None,
#                                    'exceptions': None,
#                                    'externals': None,
#                                    'get_config': None,
#                                    'logger': None,
#                                    'logging': None,
#                                    'os': None,
#                                    'random': None,
#                                    'set_config': None,
#                                    'setup_module': None,
#                                    'show_versions': None,
#                                    'sys': None,
#                                    'utils': None},
#                        'os': {'_config': None,
#                               '_distributor_init': None,
#                               'base': None,
#                               'clone': None,
#                               'config_context': None,
#                               'exceptions': None,
#                               'externals': None,
#                               'get_config': None,
#                               'logger': None,
#                               'logging': None,
#                               'os': None,
#                               'random': None,
#                               'set_config': None,
#                               'setup_module': None,
#                               'show_versions': None,
#                               'sys': None,
#                               'utils': None},
#                        'random': {'_config': None,
#                                   '_distributor_init': None,
#                                   'base': None,
#                                   'clone': None,
#                                   'config_context': None,
#                                   'exceptions': None,
#                                   'externals': None,
#                                   'get_config': None,
#                                   'logger': None,
#                                   'logging': None,
#                                   'os': None,
#                                   'random': None,
#                                   'set_config': None,
#                                   'setup_module': None,
#                                   'show_versions': None,
#                                   'sys': None,
#                                   'utils': None},
#                        'set_config': {'_config': None,
#                                       '_distributor_init': None,
#                                       'base': None,
#                                       'clone': None,
#                                       'config_context': None,
#                                       'exceptions': None,
#                                       'externals': None,
#                                       'get_config': None,
#                                       'logger': None,
#                                       'logging': None,
#                                       'os': None,
#                                       'random': None,
#                                       'set_config': None,
#                                       'setup_module': None,
#                                       'show_versions': None,
#                                       'sys': None,
#                                       'utils': None},
#                        'setup_module': {'_config': None,
#                                         '_distributor_init': None,
#                                         'base': None,
#                                         'clone': None,
#                                         'config_context': None,
#                                         'exceptions': None,
#                                         'externals': None,
#                                         'get_config': None,
#                                         'logger': None,
#                                         'logging': None,
#                                         'os': None,
#                                         'random': None,
#                                         'set_config': None,
#                                         'setup_module': None,
#                                         'show_versions': None,
#                                         'sys': None,
#                                         'utils': None},
#                        'show_versions': {'_config': None,
#                                          '_distributor_init': None,
#                                          'base': None,
#                                          'clone': None,
#                                          'config_context': None,
#                                          'exceptions': None,
#                                          'externals': None,
#                                          'get_config': None,
#                                          'logger': None,
#                                          'logging': None,
#                                          'os': None,
#                                          'random': None,
#                                          'set_config': None,
#                                          'setup_module': None,
#                                          'show_versions': None,
#                                          'sys': None,
#                                          'utils': None},
#                        'sys': {'_config': None,
#                                '_distributor_init': None,
#                                'base': None,
#                                'clone': None,
#                                'config_context': None,
#                                'exceptions': None,
#                                'externals': None,
#                                'get_config': None,
#                                'logger': None,
#                                'logging': None,
#                                'os': None,
#                                'random': None,
#                                'set_config': None,
#                                'setup_module': None,
#                                'show_versions': None,
#                                'sys': None,
#                                'utils': None},
#                        'utils': {'_config': None,
#                                  '_distributor_init': None,
#                                  'base': None,
#                                  'clone': None,
#                                  'config_context': None,
#                                  'exceptions': None,
#                                  'externals': None,
#                                  'get_config': None,
#                                  'logger': None,
#                                  'logging': None,
#                                  'os': None,
#                                  'random': None,
#                                  'set_config': None,
#                                  'setup_module': None,
#                                  'show_versions': None,
#                                  'sys': None,
#                                  'utils': None}},
#  'base': {'_config': {'_config': None,
#                       '_distributor_init': None,
#                       'base': None,
#                       'clone': None,
#                       'config_context': None,
#                       'exceptions': None,
#                       'externals': None,
#                       'get_config': None,
#                       'logger': None,
#                       'logging': None,
#                       'os': None,
#                       'random': None,
#                       'set_config': None,
#                       'setup_module': None,
#                       'show_versions': None,
#                       'sys': None,
#                       'utils': None},
#           '_distributor_init': {'_config': None,
#                                 '_distributor_init': None,
#                                 'base': None,
#                                 'clone': None,
#                                 'config_context': None,
#                                 'exceptions': None,
#                                 'externals': None,
#                                 'get_config': None,
#                                 'logger': None,
#                                 'logging': None,
#                                 'os': None,
#                                 'random': None,
#                                 'set_config': None,
#                                 'setup_module': None,
#                                 'show_versions': None,
#                                 'sys': None,
#                                 'utils': None},
#           'base': {'_config': None,
#                    '_distributor_init': None,
#                    'base': None,
#                    'clone': None,
#                    'config_context': None,
#                    'exceptions': None,
#                    'externals': None,
#                    'get_config': None,
#                    'logger': None,
#                    'logging': None,
#                    'os': None,
#                    'random': None,
#                    'set_config': None,
#                    'setup_module': None,
#                    'show_versions': None,
#                    'sys': None,
#                    'utils': None},
#           'clone': {'_config': None,
#                     '_distributor_init': None,
#                     'base': None,
#                     'clone': None,
#                     'config_context': None,
#                     'exceptions': None,
#                     'externals': None,
#                     'get_config': None,
#                     'logger': None,
#                     'logging': None,
#                     'os': None,
#                     'random': None,
#                     'set_config': None,
#                     'setup_module': None,
#                     'show_versions': None,
#                     'sys': None,
#                     'utils': None},
#           'config_context': {'_config': None,
#                              '_distributor_init': None,
#                              'base': None,
#                              'clone': None,
#                              'config_context': None,
#                              'exceptions': None,
#                              'externals': None,
#                              'get_config': None,
#                              'logger': None,
#                              'logging': None,
#                              'os': None,
#                              'random': None,
#                              'set_config': None,
#                              'setup_module': None,
#                              'show_versions': None,
#                              'sys': None,
#                              'utils': None},
#           'exceptions': {'_config': None,
#                          '_distributor_init': None,
#                          'base': None,
#                          'clone': None,
#                          'config_context': None,
#                          'exceptions': None,
#                          'externals': None,
#                          'get_config': None,
#                          'logger': None,
#                          'logging': None,
#                          'os': None,
#                          'random': None,
#                          'set_config': None,
#                          'setup_module': None,
#                          'show_versions': None,
#                          'sys': None,
#                          'utils': None},
#           'externals': {'_config': None,
#                         '_distributor_init': None,
#                         'base': None,
#                         'clone': None,
#                         'config_context': None,
#                         'exceptions': None,
#                         'externals': None,
#                         'get_config': None,
#                         'logger': None,
#                         'logging': None,
#                         'os': None,
#                         'random': None,
#                         'set_config': None,
#                         'setup_module': None,
#                         'show_versions': None,
#                         'sys': None,
#                         'utils': None},
#           'get_config': {'_config': None,
#                          '_distributor_init': None,
#                          'base': None,
#                          'clone': None,
#                          'config_context': None,
#                          'exceptions': None,
#                          'externals': None,
#                          'get_config': None,
#                          'logger': None,
#                          'logging': None,
#                          'os': None,
#                          'random': None,
#                          'set_config': None,
#                          'setup_module': None,
#                          'show_versions': None,
#                          'sys': None,
#                          'utils': None},
#           'logger': {'_config': None,
#                      '_distributor_init': None,
#                      'base': None,
#                      'clone': None,
#                      'config_context': None,
#                      'exceptions': None,
#                      'externals': None,
#                      'get_config': None,
#                      'logger': None,
#                      'logging': None,
#                      'os': None,
#                      'random': None,
#                      'set_config': None,
#                      'setup_module': None,
#                      'show_versions': None,
#                      'sys': None,
#                      'utils': None},
#           'logging': {'_config': None,
#                       '_distributor_init': None,
#                       'base': None,
#                       'clone': None,
#                       'config_context': None,
#                       'exceptions': None,
#                       'externals': None,
#                       'get_config': None,
#                       'logger': None,
#                       'logging': None,
#                       'os': None,
#                       'random': None,
#                       'set_config': None,
#                       'setup_module': None,
#                       'show_versions': None,
#                       'sys': None,
#                       'utils': None},
#           'os': {'_config': None,
#                  '_distributor_init': None,
#                  'base': None,
#                  'clone': None,
#                  'config_context': None,
#                  'exceptions': None,
#                  'externals': None,
#                  'get_config': None,
#                  'logger': None,
#                  'logging': None,
#                  'os': None,
#                  'random': None,
#                  'set_config': None,
#                  'setup_module': None,
#                  'show_versions': None,
#                  'sys': None,
#                  'utils': None},
#           'random': {'_config': None,
#                      '_distributor_init': None,
#                      'base': None,
#                      'clone': None,
#                      'config_context': None,
#                      'exceptions': None,
#                      'externals': None,
#                      'get_config': None,
#                      'logger': None,
#                      'logging': None,
#                      'os': None,
#                      'random': None,
#                      'set_config': None,
#                      'setup_module': None,
#                      'show_versions': None,
#                      'sys': None,
#                      'utils': None},
#           'set_config': {'_config': None,
#                          '_distributor_init': None,
#                          'base': None,
#                          'clone': None,
#                          'config_context': None,
#                          'exceptions': None,
#                          'externals': None,
#                          'get_config': None,
#                          'logger': None,
#                          'logging': None,
#                          'os': None,
#                          'random': None,
#                          'set_config': None,
#                          'setup_module': None,
#                          'show_versions': None,
#                          'sys': None,
#                          'utils': None},
#           'setup_module': {'_config': None,
#                            '_distributor_init': None,
#                            'base': None,
#                            'clone': None,
#                            'config_context': None,
#                            'exceptions': None,
#                            'externals': None,
#                            'get_config': None,
#                            'logger': None,
#                            'logging': None,
#                            'os': None,
#                            'random': None,
#                            'set_config': None,
#                            'setup_module': None,
#                            'show_versions': None,
#                            'sys': None,
#                            'utils': None},
#           'show_versions': {'_config': None,
#                             '_distributor_init': None,
#                             'base': None,
#                             'clone': None,
#                             'config_context': None,
#                             'exceptions': None,
#                             'externals': None,
#                             'get_config': None,
#                             'logger': None,
#                             'logging': None,
#                             'os': None,
#                             'random': None,
#                             'set_config': None,
#                             'setup_module': None,
#                             'show_versions': None,
#                             'sys': None,
#                             'utils': None},
#           'sys': {'_config': None,
#                   '_distributor_init': None,
#                   'base': None,
#                   'clone': None,
#                   'config_context': None,
#                   'exceptions': None,
#                   'externals': None,
#                   'get_config': None,
#                   'logger': None,
#                   'logging': None,
#                   'os': None,
#                   'random': None,
#                   'set_config': None,
#                   'setup_module': None,
#                   'show_versions': None,
#                   'sys': None,
#                   'utils': None},
#           'utils': {'_config': None,
#                     '_distributor_init': None,
#                     'base': None,
#                     'clone': None,
#                     'config_context': None,
#                     'exceptions': None,
#                     'externals': None,
#                     'get_config': None,
#                     'logger': None,
#                     'logging': None,
#                     'os': None,
#                     'random': None,
#                     'set_config': None,
#                     'setup_module': None,
#                     'show_versions': None,
#                     'sys': None,
#                     'utils': None}},
#  'clone': {'_config': {'_config': None,
#                        '_distributor_init': None,
#                        'base': None,
#                        'clone': None,
#                        'config_context': None,
#                        'exceptions': None,
#                        'externals': None,
#                        'get_config': None,
#                        'logger': None,
#                        'logging': None,
#                        'os': None,
#                        'random': None,
#                        'set_config': None,
#                        'setup_module': None,
#                        'show_versions': None,
#                        'sys': None,
#                        'utils': None},
#            '_distributor_init': {'_config': None,
#                                  '_distributor_init': None,
#                                  'base': None,
#                                  'clone': None,
#                                  'config_context': None,
#                                  'exceptions': None,
#                                  'externals': None,
#                                  'get_config': None,
#                                  'logger': None,
#                                  'logging': None,
#                                  'os': None,
#                                  'random': None,
#                                  'set_config': None,
#                                  'setup_module': None,
#                                  'show_versions': None,
#                                  'sys': None,
#                                  'utils': None},
#            'base': {'_config': None,
#                     '_distributor_init': None,
#                     'base': None,
#                     'clone': None,
#                     'config_context': None,
#                     'exceptions': None,
#                     'externals': None,
#                     'get_config': None,
#                     'logger': None,
#                     'logging': None,
#                     'os': None,
#                     'random': None,
#                     'set_config': None,
#                     'setup_module': None,
#                     'show_versions': None,
#                     'sys': None,
#                     'utils': None},
#            'clone': {'_config': None,
#                      '_distributor_init': None,
#                      'base': None,
#                      'clone': None,
#                      'config_context': None,
#                      'exceptions': None,
#                      'externals': None,
#                      'get_config': None,
#                      'logger': None,
#                      'logging': None,
#                      'os': None,
#                      'random': None,
#                      'set_config': None,
#                      'setup_module': None,
#                      'show_versions': None,
#                      'sys': None,
#                      'utils': None},
#            'config_context': {'_config': None,
#                               '_distributor_init': None,
#                               'base': None,
#                               'clone': None,
#                               'config_context': None,
#                               'exceptions': None,
#                               'externals': None,
#                               'get_config': None,
#                               'logger': None,
#                               'logging': None,
#                               'os': None,
#                               'random': None,
#                               'set_config': None,
#                               'setup_module': None,
#                               'show_versions': None,
#                               'sys': None,
#                               'utils': None},
#            'exceptions': {'_config': None,
#                           '_distributor_init': None,
#                           'base': None,
#                           'clone': None,
#                           'config_context': None,
#                           'exceptions': None,
#                           'externals': None,
#                           'get_config': None,
#                           'logger': None,
#                           'logging': None,
#                           'os': None,
#                           'random': None,
#                           'set_config': None,
#                           'setup_module': None,
#                           'show_versions': None,
#                           'sys': None,
#                           'utils': None},
#            'externals': {'_config': None,
#                          '_distributor_init': None,
#                          'base': None,
#                          'clone': None,
#                          'config_context': None,
#                          'exceptions': None,
#                          'externals': None,
#                          'get_config': None,
#                          'logger': None,
#                          'logging': None,
#                          'os': None,
#                          'random': None,
#                          'set_config': None,
#                          'setup_module': None,
#                          'show_versions': None,
#                          'sys': None,
#                          'utils': None},
#            'get_config': {'_config': None,
#                           '_distributor_init': None,
#                           'base': None,
#                           'clone': None,
#                           'config_context': None,
#                           'exceptions': None,
#                           'externals': None,
#                           'get_config': None,
#                           'logger': None,
#                           'logging': None,
#                           'os': None,
#                           'random': None,
#                           'set_config': None,
#                           'setup_module': None,
#                           'show_versions': None,
#                           'sys': None,
#                           'utils': None},
#            'logger': {'_config': None,
#                       '_distributor_init': None,
#                       'base': None,
#                       'clone': None,
#                       'config_context': None,
#                       'exceptions': None,
#                       'externals': None,
#                       'get_config': None,
#                       'logger': None,
#                       'logging': None,
#                       'os': None,
#                       'random': None,
#                       'set_config': None,
#                       'setup_module': None,
#                       'show_versions': None,
#                       'sys': None,
#                       'utils': None},
#            'logging': {'_config': None,
#                        '_distributor_init': None,
#                        'base': None,
#                        'clone': None,
#                        'config_context': None,
#                        'exceptions': None,
#                        'externals': None,
#                        'get_config': None,
#                        'logger': None,
#                        'logging': None,
#                        'os': None,
#                        'random': None,
#                        'set_config': None,
#                        'setup_module': None,
#                        'show_versions': None,
#                        'sys': None,
#                        'utils': None},
# ...
#                     'random': None,
#                     'set_config': None,
#                     'setup_module': None,
#                     'show_versions': None,
#                     'sys': None,
#                     'utils': None},
#          'set_config': {'_config': None,
#                         '_distributor_init': None,
#                         'base': None,
#                         'clone': None,
#                         'config_context': None,
#                         'exceptions': None,
#                         'externals': None,
#                         'get_config': None,
#                         'logger': None,
#                         'logging': None,
#                         'os': None,
#                         'random': None,
#                         'set_config': None,
#                         'setup_module': None,
#                         'show_versions': None,
#                         'sys': None,
#                         'utils': None},
#          'setup_module': {'_config': None,
#                           '_distributor_init': None,
#                           'base': None,
#                           'clone': None,
#                           'config_context': None,
#                           'exceptions': None,
#                           'externals': None,
#                           'get_config': None,
#                           'logger': None,
#                           'logging': None,
#                           'os': None,
#                           'random': None,
#                           'set_config': None,
#                           'setup_module': None,
#                           'show_versions': None,
#                           'sys': None,
#                           'utils': None},
#          'show_versions': {'_config': None,
#                            '_distributor_init': None,
#                            'base': None,
#                            'clone': None,
#                            'config_context': None,
#                            'exceptions': None,
#                            'externals': None,
#                            'get_config': None,
#                            'logger': None,
#                            'logging': None,
#                            'os': None,
#                            'random': None,
#                            'set_config': None,
#                            'setup_module': None,
#                            'show_versions': None,
#                            'sys': None,
#                            'utils': None},
#          'sys': {'_config': None,
#                  '_distributor_init': None,
#                  'base': None,
#                  'clone': None,
#                  'config_context': None,
#                  'exceptions': None,
#                  'externals': None,
#                  'get_config': None,
#                  'logger': None,
#                  'logging': None,
#                  'os': None,
#                  'random': None,
#                  'set_config': None,
#                  'setup_module': None,
#                  'show_versions': None,
#                  'sys': None,
#                  'utils': None},
#          'utils': {'_config': None,
#                    '_distributor_init': None,
#                    'base': None,
#                    'clone': None,
#                    'config_context': None,
#                    'exceptions': None,
#                    'externals': None,
#                    'get_config': None,
#                    'logger': None,
#                    'logging': None,
#                    'os': None,
#                    'random': None,
#                    'set_config': None,
#                    'setup_module': None,
#                    'show_versions': None,
#                    'sys': None,
#                    'utils': None}},
#  'utils': {'_config': {'_config': None,
#                        '_distributor_init': None,
#                        'base': None,
#                        'clone': None,
#                        'config_context': None,
#                        'exceptions': None,
#                        'externals': None,
#                        'get_config': None,
#                        'logger': None,
#                        'logging': None,
#                        'os': None,
#                        'random': None,
#                        'set_config': None,
#                        'setup_module': None,
#                        'show_versions': None,
#                        'sys': None,
#                        'utils': None},
#            '_distributor_init': {'_config': None,
#                                  '_distributor_init': None,
#                                  'base': None,
#                                  'clone': None,
#                                  'config_context': None,
#                                  'exceptions': None,
#                                  'externals': None,
#                                  'get_config': None,
#                                  'logger': None,
#                                  'logging': None,
#                                  'os': None,
#                                  'random': None,
#                                  'set_config': None,
#                                  'setup_module': None,
#                                  'show_versions': None,
#                                  'sys': None,
#                                  'utils': None},
#            'base': {'_config': None,
#                     '_distributor_init': None,
#                     'base': None,
#                     'clone': None,
#                     'config_context': None,
#                     'exceptions': None,
#                     'externals': None,
#                     'get_config': None,
#                     'logger': None,
#                     'logging': None,
#                     'os': None,
#                     'random': None,
#                     'set_config': None,
#                     'setup_module': None,
#                     'show_versions': None,
#                     'sys': None,
#                     'utils': None},
#            'clone': {'_config': None,
#                      '_distributor_init': None,
#                      'base': None,
#                      'clone': None,
#                      'config_context': None,
#                      'exceptions': None,
#                      'externals': None,
#                      'get_config': None,
#                      'logger': None,
#                      'logging': None,
#                      'os': None,
#                      'random': None,
#                      'set_config': None,
#                      'setup_module': None,
#                      'show_versions': None,
#                      'sys': None,
#                      'utils': None},
#            'config_context': {'_config': None,
#                               '_distributor_init': None,
#                               'base': None,
#                               'clone': None,
#                               'config_context': None,
#                               'exceptions': None,
#                               'externals': None,
#                               'get_config': None,
#                               'logger': None,
#                               'logging': None,
#                               'os': None,
#                               'random': None,
#                               'set_config': None,
#                               'setup_module': None,
#                               'show_versions': None,
#                               'sys': None,
#                               'utils': None},
#            'exceptions': {'_config': None,
#                           '_distributor_init': None,
#                           'base': None,
#                           'clone': None,
#                           'config_context': None,
#                           'exceptions': None,
#                           'externals': None,
#                           'get_config': None,
#                           'logger': None,
#                           'logging': None,
#                           'os': None,
#                           'random': None,
#                           'set_config': None,
#                           'setup_module': None,
#                           'show_versions': None,
#                           'sys': None,
#                           'utils': None},
#            'externals': {'_config': None,
#                          '_distributor_init': None,
#                          'base': None,
#                          'clone': None,
#                          'config_context': None,
#                          'exceptions': None,
#                          'externals': None,
#                          'get_config': None,
#                          'logger': None,
#                          'logging': None,
#                          'os': None,
#                          'random': None,
#                          'set_config': None,
#                          'setup_module': None,
#                          'show_versions': None,
#                          'sys': None,
#                          'utils': None},
#            'get_config': {'_config': None,
#                           '_distributor_init': None,
#                           'base': None,
#                           'clone': None,
#                           'config_context': None,
#                           'exceptions': None,
#                           'externals': None,
#                           'get_config': None,
#                           'logger': None,
#                           'logging': None,
#                           'os': None,
#                           'random': None,
#                           'set_config': None,
#                           'setup_module': None,
#                           'show_versions': None,
#                           'sys': None,
#                           'utils': None},
#            'logger': {'_config': None,
#                       '_distributor_init': None,
#                       'base': None,
#                       'clone': None,
#                       'config_context': None,
#                       'exceptions': None,
#                       'externals': None,
#                       'get_config': None,
#                       'logger': None,
#                       'logging': None,
#                       'os': None,
#                       'random': None,
#                       'set_config': None,
#                       'setup_module': None,
#                       'show_versions': None,
#                       'sys': None,
#                       'utils': None},
#            'logging': {'_config': None,
#                        '_distributor_init': None,
#                        'base': None,
#                        'clone': None,
#                        'config_context': None,
#                        'exceptions': None,
#                        'externals': None,
#                        'get_config': None,
#                        'logger': None,
#                        'logging': None,
#                        'os': None,
#                        'random': None,
#                        'set_config': None,
#                        'setup_module': None,
#                        'show_versions': None,
#                        'sys': None,
#                        'utils': None},
#            'os': {'_config': None,
#                   '_distributor_init': None,
#                   'base': None,
#                   'clone': None,
#                   'config_context': None,
#                   'exceptions': None,
#                   'externals': None,
#                   'get_config': None,
#                   'logger': None,
#                   'logging': None,
#                   'os': None,
#                   'random': None,
#                   'set_config': None,
#                   'setup_module': None,
#                   'show_versions': None,
#                   'sys': None,
#                   'utils': None},
#            'random': {'_config': None,
#                       '_distributor_init': None,
#                       'base': None,
#                       'clone': None,
#                       'config_context': None,
#                       'exceptions': None,
#                       'externals': None,
#                       'get_config': None,
#                       'logger': None,
#                       'logging': None,
#                       'os': None,
#                       'random': None,
#                       'set_config': None,
#                       'setup_module': None,
#                       'show_versions': None,
#                       'sys': None,
#                       'utils': None},
#            'set_config': {'_config': None,
#                           '_distributor_init': None,
#                           'base': None,
#                           'clone': None,
#                           'config_context': None,
#                           'exceptions': None,
#                           'externals': None,
#                           'get_config': None,
#                           'logger': None,
#                           'logging': None,
#                           'os': None,
#                           'random': None,
#                           'set_config': None,
#                           'setup_module': None,
#                           'show_versions': None,
#                           'sys': None,
#                           'utils': None},
#            'setup_module': {'_config': None,
#                             '_distributor_init': None,
#                             'base': None,
#                             'clone': None,
#                             'config_context': None,
#                             'exceptions': None,
#                             'externals': None,
#                             'get_config': None,
#                             'logger': None,
#                             'logging': None,
#                             'os': None,
#                             'random': None,
#                             'set_config': None,
#                             'setup_module': None,
#                             'show_versions': None,
#                             'sys': None,
#                             'utils': None},
#            'show_versions': {'_config': None,
#                              '_distributor_init': None,
#                              'base': None,
#                              'clone': None,
#                              'config_context': None,
#                              'exceptions': None,
#                              'externals': None,
#                              'get_config': None,
#                              'logger': None,
#                              'logging': None,
#                              'os': None,
#                              'random': None,
#                              'set_config': None,
#                              'setup_module': None,
#                              'show_versions': None,
#                              'sys': None,
#                              'utils': None},
#            'sys': {'_config': None,
#                    '_distributor_init': None,
#                    'base': None,
#                    'clone': None,
#                    'config_context': None,
#                    'exceptions': None,
#                    'externals': None,
#                    'get_config': None,
#                    'logger': None,
#                    'logging': None,
#                    'os': None,
#                    'random': None,
#                    'set_config': None,
#                    'setup_module': None,
#                    'show_versions': None,
#                    'sys': None,
#                    'utils': None},
#            'utils': {'_config': None,
#                      '_distributor_init': None,
#                      'base': None,
#                      'clone': None,
#                      'config_context': None,
#                      'exceptions': None,
#                      'externals': None,
#                      'get_config': None,
#                      'logger': None,
#                      'logging': None,
#                      'os': None,
#                      'random': None,
#                      'set_config': None,
#                      'setup_module': None,
#                      'show_versions': None,
#                      'sys': None,
#                      'utils': None}}}
